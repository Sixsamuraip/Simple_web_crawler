# %% [markdown]
# <a href="https://colab.research.google.com/github/Sixsamuraip/Simple_web_crawler/blob/main/Simple_web_crawler_Pieng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Web Crawler Implementation
#
# A simple web crawler designed here is composed of 4 main modules:
# * <b>Scheduler</b>: maintain a queue of URLs to visit
# * <b>Downloader</b>: download web pages
# * <b>Analyzer</b>: analyze content and links
# * <b>Storage</b>: store content and metadata
#
# ## 1) Basic Downloader
# Every web crawler should be defined a <i>name</i> and identified its <i>owner</i> (i.e., the '`user-agent`' and '`from`' fields of the headers, respectively). Sometimes, you may get an error message, caused by the connection timeout and the page not found, for instance. You can print '`response.status_code`' to track that problem.

# %%
import requests
from requests.exceptions import HTTPError

headers = {
    'User-Agent': '6110500135_porpieng',
    'From': 'porpieng.n@ku.th'
}
seed_url = 'https://www.ku.ac.th/th'

def get_page(url):
    global headers
    text = ''
    try:
        response = requests.get(url, headers=headers, timeout=2)
        # If the response was successful, no Exception will be raised
        response.raise_for_status()
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')  # Python 3.6
    except Exception as err:
        print(f'Other error occurred: {err}')  # Python 3.6
    else:
        print('Success!')
        text = response.text
    return text.lower()

raw_html = get_page(seed_url)
print(raw_html)
# Out:
# Success!
# <!doctype html>
# <html lang="th">
#
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#   <meta http-equiv="x-ua-compatible" content="ie=edge">
#   <title>มหาวิทยาลัยเกษตรศาสตร์</title>
#
#   <meta name="keywords" content="ku,kasetsart university,มหาวิทยาลัยเกษตรศาสตร์"/>
# <meta name="description" content="มหาวิทยาลัยเกษตรศาสตร์ สร้างสรรค์ศาสตร์แห่งแผ่นดินสู่สากลเพื่อพัฒนาประเทศอย่างยั่งยืน kasetsart university is a public research university in bangkok,..." />
# <meta property="og:site_name" content="www.ku.ac.th"/>
# <meta property="og:locale" content="th_th"/>
# <meta property="og:type" content="website"/>
# <meta property="og:title" content="ku | มหาวิทยาลัยเกษตรศาสตร์ รอบรั้วชาวนนทรี" />
# <meta property="og:url" content="https://www.ku.ac.th/th"/>
# <meta property="og:image" content="https://www.ku.ac.th/assets/ku_logo.png" />
# <meta property="og:description" content="มหาวิทยาลัยเกษตรศาสตร์ สร้างสรรค์ศาสตร์แห่งแผ่นดินสู่สากลเพื่อพัฒนาประเทศอย่างยั่งยืน kasetsart university is a public research university in bangkok,..."/>
#   <!-- web fonts -->
#   <link rel="stylesheet" href="/assets/css/web_fonts.css" type="text/css">
#   <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.8.1/css/all.css" type="text/css">
#   <link rel="stylesheet" href="/assets/css/header.css" type="text/css">
#   <!-- style for intro event page. -->
#   <link rel="stylesheet" href="/assets/css/intro-event/intro-event.css?v=1609043294" type="text/css">
#   <style>
#     .intro-link {
#       cursor: pointer;
#     }
#   </style>
#
#       <script type="text/javascript">
#         (function(c,l,a,r,i,t,y){
#             c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#             t=l.createelement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#             y=l.getelementsbytagname(r)[0];y.parentnode.insertbefore(t,y);
#         })(window, document, "clarity", "script", "4hhdgteqtk");
#     </script>
#
# </head>
#
# <body data-clarity-unmask="true">
#     <style>
#   @media (max-width: 1920px) {
#       #introevent .intro-links {
#         padding-top: 0.5rem;
#       }
#   }
#   .enter-site-wrapper {
#     width: 100%;
#     text-align: center;
#     display: flex;
#     justify-content: center;
#     margin-bottom: 1.8rem;
#   }
#
#   .btn-enter-site {
#     width: 300px;
#   }
#
#   .btn-enter-site a {
#     color: #fff;
#     text-decoration: none;
#     font-size: 1.8rem;
#   }
#
#   @media (max-width : 600px){
#       .btn-enter-site .header-box>i {
#         font-size: 1.8rem;
#       }
#   }
#
#   #introevent .intro-links .hover-effect-wrapper {
#     z-index: 5;
#   }
#
#   </style>
#   <div id="introevent">
#
#   <a href="/th/community-home" target="_blank"  class="intro-click"></a>
#       <!-- snow -->
#     <div class="snow">
#       <svg xmlns="http://www.w3.org/2000/svg" viewbox="0 0 1024 1536" preserveaspectratio="xmidymax slice">
#         <g fill="#fff" fill-opacity=".15" transform="translate(55 42)">
#           <g id="snow-bottom-layer">
#             <ellipse cx="6" cy="1009.5" rx="6" ry="5.5" />
#             <ellipse cx="138" cy="1110.5" rx="6" ry="5.5" />
#             <ellipse cx="398" cy="1055.5" rx="6" ry="5.5" />
#             <ellipse cx="719" cy="1284.5" rx="6" ry="5.5" />
#             <ellipse cx="760" cy="1155.5" rx="6" ry="5.5" />
#             <ellipse cx="635" cy="1459.5" rx="6" ry="5.5" />
#             <ellipse cx="478" cy="1335.5" rx="6" ry="5.5" />
#             <ellipse cx="322" cy="1414.5" rx="6" ry="5.5" />
#             <ellipse cx="247" cy="1234.5" rx="6" ry="5.5" />
#             <ellipse cx="154" cy="1425.5" rx="6" ry="5.5" />
#             <ellipse cx="731" cy="773.5" rx="6" ry="5.5" />
#             <ellipse cx="599" cy="874.5" rx="6" ry="5.5" />
#             <ellipse cx="339" cy="819.5" rx="6" ry="5.5" />
#             <ellipse cx="239" cy="1004.5" rx="6" ry="5.5" />
#             <ellipse cx="113" cy="863.5" rx="6" ry="5.5" />
#             <ellipse cx="102" cy="1223.5" rx="6" ry="5.5" />
#             <ellipse cx="395" cy="1155.5" rx="6" ry="5.5" />
#             <ellipse cx="826" cy="943.5" rx="6" ry="5.5" />
#             <ellipse cx="626" cy="1054.5" rx="6" ry="5.5" />
#             <ellipse cx="887" cy="1366.5" rx="6" ry="5.5" />
#             <ellipse cx="6" cy="241.5" rx="6" ry="5.5" />
#             <ellipse cx="138" cy="342.5" rx="6" ry="5.5" />
#             <ellipse cx="398" cy="287.5" rx="6" ry="5.5" />
#             <ellipse cx="719" cy="516.5" rx="6" ry="5.5" />
#             <ellipse cx="760" cy="387.5" rx="6" ry="5.5" />
#             <ellipse cx="635" cy="691.5" rx="6" ry="5.5" />
#             <ellipse cx="478" cy="567.5" rx="6" ry="5.5" />
#             <ellipse cx="322" cy="646.5" rx="6" ry="5.5" />
#             <ellipse cx="247" cy="466.5" rx="6" ry="5.5" />
#             <ellipse cx="154" cy="657.5" rx="6" ry="5.5" />
#             <ellipse cx="731" cy="5.5" rx="6" ry="5.5" />
#             <ellipse cx="599" cy="106.5" rx="6" ry="5.5" />
#             <ellipse cx="339" cy="51.5" rx="6" ry="5.5" />
#             <ellipse cx="239" cy="236.5" rx="6" ry="5.5" />
#             <ellipse cx="113" cy="95.5" rx="6" ry="5.5" />
#             <ellipse cx="102" cy="455.5" rx="6" ry="5.5" />
#             <ellipse cx="395" cy="387.5" rx="6" ry="5.5" />
#             <ellipse cx="826" cy="175.5" rx="6" ry="5.5" />
#             <ellipse cx="626" cy="286.5" rx="6" ry="5.5" />
#             <ellipse cx="887" cy="598.5" rx="6" ry="5.5" />
#           </g>
#         </g>
#         <g fill="#fff" fill-opacity=".3" transform="translate(65 63)">
#           <g id="snow-top-layer">
#             <circle cx="8" cy="776" r="8" />
#             <circle cx="189" cy="925" r="8" />
#             <circle cx="548" cy="844" r="8" />
#             <circle cx="685" cy="1115" r="8" />
#             <circle cx="858" cy="909" r="8" />
#             <circle cx="874" cy="1438" r="8" transform="rotate(180 874 1438)" />
#             <circle cx="657" cy="1256" r="8" transform="rotate(180 657 1256)" />
#             <circle cx="443" cy="1372" r="8" transform="rotate(180 443 1372)" />
#             <circle cx="339" cy="1107" r="8" transform="rotate(180 339 1107)" />
#             <circle cx="24" cy="1305" r="8" transform="rotate(180 24 1305)" />
#             <circle cx="8" cy="8" r="8" />
#             <circle cx="189" cy="157" r="8" />
#             <circle cx="548" cy="76" r="8" />
#             <circle cx="685" cy="347" r="8" />
#             <circle cx="858" cy="141" r="8" />
#             <circle cx="874" cy="670" r="8" transform="rotate(180 874 670)" />
#             <circle cx="657" cy="488" r="8" transform="rotate(180 657 488)" />
#             <circle cx="443" cy="604" r="8" transform="rotate(180 443 604)" />
#             <circle cx="339" cy="339" r="8" transform="rotate(180 339 339)" />
#             <circle cx="24" cy="537" r="8" transform="rotate(180 24 537)" />
#           </g>
#         </g>
#       </svg>
#     </div>
#
#     <!-- banner -->
#         <div class="intro-banner" data-link="/community-home" data-target="_blank"
#     style="
#         background-image : url('/web-upload/202012/m_banner/27/img_b014ee1e4c2a3233ccf1008289fd8f05.jpg');
#     "></div>
#
#     <!-- links -->
#
#
#
#     <div class="intro-links">
#         <!--<div class="enter-site-wrapper">
#         <div class="btn-enter-site">
#             <a href="/th/community-home">
#             <div class="visit-btn header-box corner-green-light bg-black d-flex align-items-center header-box-animated header-box-animated-dark">
#                 <i class="fa fa-arrow-up"></i>
#                 <span class="text"> เข้าสู่เว็บไซต์ <span>
#             </div>
#         </a>
#         </div>
#
#     </div>-->
#
# <!-- logo ku -->
# <!--<div class="hover-effect-wrapper logo-wrapper" style="
#     text-align: center;
# ">
#         <img src="/assets/images/header/ku_logo_62x62_th.svg" alt="ku logo"  class="logo" style="">
#         <img src="/assets/images/header/ku_name_logo_62x62.svg" alt="ku name logo" class="logo" style="">
#
#        <div class="zone-name">
#             <span style="
#     font-size: 1.3rem;
#     color: #006664;
#     font-weight: 500;
#     line-height: 0.3;
# ">สร้างสรรค์ศาสตร์แห่งแผ่นดินสู่สากล</span><br><span style="
#     font-size: 1.1rem;
#     line-height: 0.1;
# ">เพื่อพัฒนาประเทศอย่างยั่งยืน</span>
#
#           </div>
#
#       </div> -->
# <!-- end logo ku  -->
#
#       <a href="/th/community-home" class="hover-effect-wrapper">
#         <div class="intro-link community-link">
#           <div class="zone-description">
#           อัปเดทข่าวสารรอบรั้วชาวนนทรี
#             <i class="fa fa-chevron-right"></i>
#           </div>
#           <div class="zone-name">
#             <span>community</span>
#             <span>zone</span>
#           </div>
#         </div>
#         <div class="zone-detail">
#           สำหรับนิสิต บุคลากร ศิษย์เก่า รวมถึงผู้สนใจทั่วไปที่ต้องการติดตามข้อมูลข่าวสาร กิจกรรมความเคลื่อนไหวต่าง ๆ ภายในมหาวิทยาลัย
#         </div>
#       </a>
#       <a href="/th/newcomer-home" class="hover-effect-wrapper">
#         <div class="intro-link newcomer-link">
#           <div class="zone-description">
#             เลือกเรียนคณะไหนดี
#             <i class="fa fa-chevron-right"></i>
#           </div>
#           <div class="zone-name">
#             <span>newcomer</span>
#             <span style="font-size: 2.14rem">prospective students</span>
#           </div>
#         </div>
#         <div class="zone-detail">
#         สำหรับนักเรียนหรือผู้ปกครองที่สนใจหรือต้องการเรียนต่อภายในมหาวิทยาลัย ค้นหาคณะ หลักสูตรที่สนใจได้ที่นี่
#         </div>
#       </a>
#       <a href="/th/partner-home" class="hover-effect-wrapper">
#         <div class="intro-link partner-link">
#           <div class="zone-description">
#             ชมผลงานและงานวิจัยเด่นๆ
#             <i class="fa fa-chevron-right"></i>
#           </div>
#           <div class="zone-name">
#             <span>partner</span>
#             <span>zone</span>
#           </div>
#         </div>
#         <div class="zone-detail">
#         สำหรับผู้สนใจในงานวิจัยต่าง ๆ ของมหาวิทยาลัย
#         </div>
#       </a>
#       <div class="copyright">
#         สงวนลิขสิทธิ์ &copy; มหาวิทยาลัยเกษตรศาสตร์
#       </div>
#     </div>
#
#   </div>
# </body>
#
# </html>

# %% [markdown]
# ## 2) Basic Analyzer
# ### 2.1 Link Parser
# The following code is an example of simple link parser. The program extracts all links by considering the <i>anchor</i> tag only, and stores them into a `urls` list.

# %%
def link_parser(raw_html):
    urls = [];
    pattern_start = '<a href="';  pattern_end = '"'
    index = 0;  length = len(raw_html)
    while index < length:
        start = raw_html.find(pattern_start, index)
        if start > 0:
            start = start + len(pattern_start)
            end = raw_html.find(pattern_end, start)
            link = raw_html[start:end]
            if len(link) > 0:
                if link not in urls:
                    urls.append(link)
            index = end
        else:
            break
    return urls

raw_html = '<html><body><a href="http://test1.com">test1</a><br><a href="http://test2.com">test2</a></body></html>'
print(link_parser(raw_html))
# Out:
# ['http://test1.com', 'http://test2.com']

# %% [markdown]
# ### 2.2 URL Normalization
# The following code is an example of using the `urljoin()` function to transform a relative URL to the absolute one.

# %%
from urllib.parse import urljoin

# Define an absolute (base) URL of a web page
base_url = 'https://mike.cpe.ku.ac.th'

# An example of the extracted absolute link
link_1 = 'http://www.ku.ac.th'
# An example of the extracted relative link
link_2 = 'download/homework.html'

base = 'https://www.ku.ac.th/th/'
link_3 = '/th/community-home'

# Resolve links
abs_link_1 = urljoin(base_url, link_1)
abs_link_2 = urljoin(base_url, link_2)

print(abs_link_1)  # -> http://www.ku.ac.th
print(abs_link_2)  # -> https://mike.cpe.ku.ac.th/download/homework.html
# Out:
# http://www.ku.ac.th
# https://mike.cpe.ku.ac.th/download/homework.html

# %% [markdown]
# ## 3) Basic Scheduler
# The following code is an example of using a FIFO queue to handle the extracted URLs to be further downloaded. In particular, the main crawling process simply invokes the previous two defined functions, i.e., `get_page()` and `link_parser()`, to first download a web page and extract its out-going links, respectively. Then, all extracted links will be stored into a queue. We define here two queues: `frontier_q` and `visited_q`. The former is used as the FIFO queue to keep URLs for next downloading, while the latter is used to remember which web pages have been already downloaded.

# %%
seed_url = 'https://www.ku.ac.th/th'
frontier_q = [seed_url]
visited_q = []

variable_name = ""
def enqueue(links):
    global frontier_q
    for link in links:
        if link not in frontier_q and link not in visited_q:
            frontier_q.append(link)

# FIFO queue
def dequeue():
    global frontier_q
    current_url = frontier_q[0]
    frontier_q = frontier_q[1:]
    return current_url

#--- main process ---#
current_url = dequeue()
visited_q.append(current_url)
raw_html = get_page(current_url)
extracted_links = link_parser(raw_html)
enqueue(extracted_links)
print(frontier_q)
# Out:
# Success!
# ['/th/community-home', '/th/newcomer-home', '/th/partner-home']

# %% [markdown]
# ## 4) Storing Text into a File
# As the following, we use the `os.makedirs()` function to first create (sub)directories. Notice that the `exist_ok=True` parameter is set to prevent an exception error if the target directory already exists. Then, we use the `open()`, `write()`, and `close()` functions to open a file, write some text into that file, and afterwards close it. In addition, we import the `codecs` module together with using the '`utf-8`' encoding for non-English content.

# %%
import os, codecs

# Create (sub)directories with the 0o755 permission
# @param 'exist_ok' is True for no exception if the target directory already exists
path = 'html/subdir1/subdir3'
os.makedirs(path, 0o755, exist_ok=True)

# Write content into a file
raw_html = '<html><body><a href="http://test1.com">test1</a><br><a href="http://test2.com">test2</a></body></html>'
abs_file = path + '/index.html'
f = codecs.open(abs_file, 'w', 'utf-8')
f.write(raw_html)
f.close()

# %% [markdown]
# # <font color="blue">Your Turn ...</font>
# Write a web crawler to collect 10,000 web pages (including only '`.htm`' and '`.html`' files) within the '`ku.ac.th`' domain.

# %%
import re
from urllib.parse import urljoin,unquote
import requests
import os, codecs
from requests.exceptions import HTTPError


headers = {
    'User-Agent': '6110500135_porpieng',
    'From': 'porpieng.n@ku.th'
}
seed_url = 'https://www.ku.ac.th/th'

page_count = 0

def get_page(url):
    global headers
    global page_count
    global page_err
    global robot_err
    text = ''
    try:
        response = requests.get(url, headers=headers, timeout=10)
        # If the response was successful, no Exception will be raised
        response.raise_for_status()
    except HTTPError as http_err:
        if 'robots.txt' in url:
            robot_err = True
        else:
            page_err = True
        print(f'HTTP error occurred: {http_err}')  # Python 3.6
    except Exception as err:
        if 'robots.txt' in url:
            robot_err = True
        else:
            page_err = True
        print(f'Other error occurred: {err}')  # Python 3.6
    else:
        print('Success!')
        if 'robots.txt' not in url:
            page_count += 1
        text = response.text
    return text.lower()


# def link_parser(raw_html):
#     urls = [];
#     regex_http = "^((http[s]?|ftp):\/)?\/?([^:\/\s]+)((\/\w+)*\/)([\w\-\.]+[^#?\s]+)(.*)?(#[\w\-]+)?$"
#     urls = re.findall(regex_http,raw_html)
#     return urls

def link_parser(raw_html):
    urls = []
    pattern_start = '<a href="';  pattern_end = '"'
    index = 0;  length = len(raw_html)
    while index < length:
        start = raw_html.find(pattern_start, index)
        if start > 0:
            start = start + len(pattern_start)
            end = raw_html.find(pattern_end, start)
            link = raw_html[start:end]
            if len(link) > 0:
                if link not in urls:
                    urls.append(unquote(link))
            index = end
        else:
            break
    return urls

def is_pdf(raw_html):
    if raw_html[(len(raw_html)-4):len(raw_html)] == '.pdf':
        return True
    else:
        return False


seed_url = 'https://www.ku.ac.th/th'
frontier_q = [seed_url]
visited_q = []

variable_name = ""
def enqueue(links):
    global frontier_q
    for link in links:
        if link not in frontier_q and link not in visited_q:
            frontier_q.append(link)

# FIFO queue
def dequeue():
    global frontier_q
    current_url = frontier_q[0]
    frontier_q = frontier_q[1:]
    return current_url


###############################################
abs_link = 'https://www.ku.ac.th/th'
current_url = ''
page_err = False
robot_err = False
abs_visited = []

while (page_count < 10500):
    try:
        page_err = False
        robot_err = False
        current_url = dequeue()
        abs_link = urljoin(seed_url, current_url)
        if is_pdf(abs_link) :
            continue
        if 'download' in abs_link:
            continue
        if 'ku.ac.th' not in abs_link:
            continue
        if abs_link not in abs_visited:
            abs_visited.append(abs_link)
        else:
            continue
        print('absolute path is :',abs_link)

        raw_html = get_page(abs_link)

        links = link_parser(raw_html)
        visited_q.append(current_url)
        #print(links)
        extracted_links = links
        enqueue(extracted_links)
        if page_err:
            continue

        robot_link = abs_link + '/robots.txt'
        #print(robot_link)
        raw_robot = get_page(robot_link)


        file_link = abs_link
        file_link = file_link.replace('https://','')
        file_link = file_link.replace('http://','')
        file_link = file_link.replace('?','{question}')
        file_link = file_link.replace('*','{star}')
        path = 'html/' + file_link
        #print('current path :',path)
        os.makedirs(path, 0o755, exist_ok=True)

        # Write content into a file
        abs_file = path + '/index.html'
        f = codecs.open(abs_file, 'w', 'utf-8')
        f.write(raw_html)
        f.close()
        print('file suscessfil save at',abs_file)

        if ('user-agent' in raw_robot) and (robot_err == False):
            robot_file = path + '/robots.txt'
            r = codecs.open(robot_file, 'w', 'utf-8')
            r.write(raw_robot)
            r.close()

            ro = codecs.open('html/list_robot.txt', 'a', 'utf-8')
            ro.write(abs_link + '\n')
            ro.close()
            print(robot_link,' have robots.txt')

        print('now have',page_count,'page')
        print('')
        #print(frontier_q)
        #print(visited_q)
    except :
        skip = dequeue()
        print('error')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a = 'html/'
b = 'https://www.ku.ac.th/th/'
b = b.replace('https://','')
c = a+b
print(c)
# Out:
# html/www.ku.ac.th/th/

# %%
base = 'https://www.ku.ac.th/th/'
link = ''
ans = urljoin(link,base)
print(ans)
# Out:
# https://www.ku.ac.th/th/

# %%
rm -rf html/

# %%
# !zip -r /content/test.zip /content/html
# Out:
#   adding: content/html/ (stored 0%)
#   adding: content/html/clgc.agri.kps.ku.ac.th/ (stored 0%)
#   adding: content/html/clgc.agri.kps.ku.ac.th/index.html (deflated 82%)
#   adding: content/html/askme.registrar.ku.ac.th/ (stored 0%)
#   adding: content/html/askme.registrar.ku.ac.th/contact-us/ (stored 0%)
#   adding: content/html/askme.registrar.ku.ac.th/contact-us/index.html (deflated 75%)
#   adding: content/html/kuappstore.ku.ac.th/ (stored 0%)
#   adding: content/html/kuappstore.ku.ac.th/index.html (deflated 85%)
#   adding: content/html/annualconference.ku.ac.th/ (stored 0%)
#   adding: content/html/annualconference.ku.ac.th/index.html (deflated 77%)
#   adding: content/html/annualconference.ku.ac.th/index.php/ (stored 0%)
#   adding: content/html/annualconference.ku.ac.th/index.php/index.html (deflated 77%)
#   adding: content/html/mis.grad.ku.ac.th/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/faculty/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/faculty/register/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/faculty/register/index.html (deflated 67%)
#   adding: content/html/mis.grad.ku.ac.th/recruitment/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/recruitment/report/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/recruitment/report/th/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/recruitment/report/th/all/ (stored 0%)
#   adding: content/html/mis.grad.ku.ac.th/recruitment/report/th/all/index.html (deflated 72%)
#   adding: content/html/edufarm.ku.ac.th/ (stored 0%)
#   adding: content/html/edufarm.ku.ac.th/index.html (deflated 77%)
#   adding: content/html/live.ku.ac.th/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=175/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=175/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=บัตเตอร์เค้ก/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=บัตเตอร์เค้ก/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=social-networking/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=social-networking/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำยาเห็ด/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำยาเห็ด/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=1/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=1/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}p=7772/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7772/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=virtualization/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=virtualization/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=9/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=9/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=cat-tetecom/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=cat-tetecom/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=11/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=11/index.html (deflated 84%)
#   adding: content/html/live.ku.ac.th/{question}tag=พิชิตใจวัยรุ่น/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=พิชิตใจวัยรุ่น/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=168/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=168/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=งานประจำ/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=งานประจำ/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=สอบตรง/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=สอบตรง/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำนมถั่วเหลือง/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำนมถั่วเหลือง/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=14/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=14/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำยาถูพื้น/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำยาถูพื้น/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=8/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=8/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}cat=192/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=192/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=ไก่/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ไก่/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=ถั่วงอกอนามัย/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ถั่วงอกอนามัย/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=งานได้ผล/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=งานได้ผล/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=ไข่่ตุ๋นญี่ปุ่น/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ไข่่ตุ๋นญี่ปุ่น/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=เพิ่มผลผลิตพืชด้วยมูลส/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=เพิ่มผลผลิตพืชด้วยมูลส/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=คนเป็นสุข/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=คนเป็นสุข/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=13/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=13/index.html (deflated 83%)
#   adding: content/html/live.ku.ac.th/{question}tag=สมอง/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=สมอง/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}cat=19/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=19/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=วิจัย/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=วิจัย/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=ภัยธรรมชาติ/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ภัยธรรมชาติ/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=หญ้าหวาน/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=หญ้าหวาน/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=156/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=156/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}cat=78/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=78/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}p=7701/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7701/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}p=7734/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7734/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=7/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=7/index.html (deflated 83%)
#   adding: content/html/live.ku.ac.th/{question}cat=18/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=18/index.html (deflated 85%)
#   adding: content/html/live.ku.ac.th/{question}tag=จิตเบิกบาน/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=จิตเบิกบาน/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=3g/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=3g/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=เด็กพิเศษ/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=เด็กพิเศษ/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}page_id=2/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}page_id=2/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=แนะแนว/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=แนะแนว/index.html (deflated 83%)
#   adding: content/html/live.ku.ac.th/{question}p=7165/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7165/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=มาม่อนเค้ก/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=มาม่อนเค้ก/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=หมูทอด/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=หมูทอด/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=กองแผนงาน/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=กองแผนงาน/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}p=7789/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7789/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=4/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=4/index.html (deflated 83%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำนมข้าวโพด/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำนมข้าวโพด/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}page_id=5282/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}page_id=5282/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=ปรับตัว/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ปรับตัว/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=การเกษตร/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=การเกษตร/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}p=7634/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7634/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=โดนัท/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=โดนัท/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=มังคุด/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=มังคุด/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}p=7637/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7637/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=17/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=17/index.html (deflated 85%)
#   adding: content/html/live.ku.ac.th/{question}tag=สังฆภัณฑ์/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=สังฆภัณฑ์/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=e-learning/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=e-learning/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=6/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=6/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=cloud-computing/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=cloud-computing/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=อาเซียน/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=อาเซียน/index.html (deflated 83%)
#   adding: content/html/live.ku.ac.th/{question}tag=ปลา/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ปลา/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}cat=190/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=190/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}cat=172/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=172/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำยาล้างจาน/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=น้ำยาล้างจาน/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=166/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=166/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}page_id=124/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}page_id=124/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=157/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=157/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=4g/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=4g/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}p=7770/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}p=7770/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=10/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=10/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=km/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=km/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}tag=สังขยาใบเตย/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=สังขยาใบเตย/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=cloud-learning/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=cloud-learning/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=ประกันคุณภาพ/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=ประกันคุณภาพ/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}tag=แอดมิชชั่น/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=แอดมิชชั่น/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}tag=web-2-0/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}tag=web-2-0/index.html (deflated 81%)
#   adding: content/html/live.ku.ac.th/{question}cat=77/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=77/index.html (deflated 82%)
#   adding: content/html/live.ku.ac.th/{question}page_id=4862/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}page_id=4862/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}page_id=4024/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}page_id=4024/index.html (deflated 80%)
#   adding: content/html/live.ku.ac.th/{question}cat=47/ (stored 0%)
#   adding: content/html/live.ku.ac.th/{question}cat=47/index.html (deflated 82%)
#   adding: content/html/www.sbc.ku.ac.th/ (stored 0%)
#   adding: content/html/www.sbc.ku.ac.th/{question}page_id=3828/ (stored 0%)
#   adding: content/html/www.sbc.ku.ac.th/{question}page_id=3828/index.html (deflated 81%)
#   adding: content/html/www.sbc.ku.ac.th/index.html (deflated 87%)
#   adding: content/html/www.inf.ku.ac.th/ (stored 0%)
#   adding: content/html/www.inf.ku.ac.th/robots.txt (deflated 54%)
#   adding: content/html/www.inf.ku.ac.th/index.html (deflated 58%)
#   adding: content/html/www.eto.ku.ac.th/ (stored 0%)
#   adding: content/html/www.eto.ku.ac.th/hrd/ (stored 0%)
#   adding: content/html/www.eto.ku.ac.th/hrd/index.php/ (stored 0%)
#   adding: content/html/www.eto.ku.ac.th/hrd/index.php/index.html (deflated 85%)
#   adding: content/html/sis.ku.ac.th/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/นิทรรศการ-sis-semester-inspired-summary-1/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/นิทรรศการ-sis-semester-inspired-summary-1/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/ช่องทางการติดต่อวิทยาล/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/ช่องทางการติดต่อวิทยาล/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/tcas-64/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/tcas-64/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/calendar/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/calendar/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/edufarm/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/edufarm/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/management/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/management/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/structure/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/structure/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/ประกาศรับสมัครชุดวิชา-non-degree/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/ประกาศรับสมัครชุดวิชา-non-degree/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/klsd/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/klsd/robots.txt (deflated 28%)
#   adding: content/html/sis.ku.ac.th/klsd/index.html (deflated 84%)
#   adding: content/html/sis.ku.ac.th/km/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/km/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/portfolio/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/portfolio/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/multimedia/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/multimedia/index.html (deflated 81%)
#   adding: content/html/sis.ku.ac.th/vision/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/vision/index.html (deflated 78%)
#   adding: content/html/sis.ku.ac.th/robots.txt (deflated 26%)
#   adding: content/html/sis.ku.ac.th/announcement/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/announcement/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/news-activities/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/news-activities/index.html (deflated 81%)
#   adding: content/html/sis.ku.ac.th/staff-member/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/staff-member/index.html (deflated 83%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0002/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0002/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0003/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0003/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0001/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0001/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0005/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0005/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0004/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/รายวิชาบรูณาการ/#sis0004/index.html (deflated 79%)
#   adding: content/html/sis.ku.ac.th/quick-links/ (stored 0%)
#   adding: content/html/sis.ku.ac.th/quick-links/index.html (deflated 79%)
#   adding: content/html/www.ifrpd.ku.ac.th/ (stored 0%)
#   adding: content/html/www.ifrpd.ku.ac.th/th/ (stored 0%)
#   adding: content/html/www.ifrpd.ku.ac.th/th/products/ (stored 0%)
#   adding: content/html/www.ifrpd.ku.ac.th/th/products/training-services.php/ (stored 0%)
#   adding: content/html/www.ifrpd.ku.ac.th/th/products/training-services.php/index.html (deflated 80%)
#   adding: content/html/www.lib.ku.ac.th/ (stored 0%)
#   adding: content/html/www.lib.ku.ac.th/index.html (deflated 61%)
#   adding: content/html/www.csc.ku.ac.th/ (stored 0%)
#   adding: content/html/www.csc.ku.ac.th/index.html (deflated 51%)
#   adding: content/html/www.csc.ku.ac.th/th/ (stored 0%)
#   adding: content/html/www.csc.ku.ac.th/th/index.html (deflated 84%)
#   adding: content/html/agkc.lib.ku.ac.th/ (stored 0%)
#   adding: content/html/agkc.lib.ku.ac.th/agkc/ (stored 0%)
#   adding: content/html/agkc.lib.ku.ac.th/agkc/index.html/ (stored 0%)
#   adding: content/html/agkc.lib.ku.ac.th/agkc/index.html/index.html (deflated 36%)
#   adding: content/html/www3.rdi.ku.ac.th/ (stored 0%)
#   adding: content/html/www3.rdi.ku.ac.th/{question}p=36145/ (stored 0%)
#   adding: content/html/www3.rdi.ku.ac.th/{question}p=36145/index.html (deflated 86%)
#   adding: content/html/eto.ku.ac.th/ (stored 0%)
#   adding: content/html/eto.ku.ac.th/index.html (deflated 82%)
#   adding: content/html/ogrf.grad.ku.ac.th/ (stored 0%)
#   adding: content/html/ogrf.grad.ku.ac.th/published/ (stored 0%)
#   adding: content/html/ogrf.grad.ku.ac.th/published/index.html (deflated 57%)
#   adding: content/html/ogrf.grad.ku.ac.th/request/ (stored 0%)
#   adding: content/html/ogrf.grad.ku.ac.th/request/index.html (deflated 81%)
#   adding: content/html/ogrf.grad.ku.ac.th/report4study/ (stored 0%)
#   adding: content/html/ogrf.grad.ku.ac.th/report4study/index.html (deflated 95%)
#   adding: content/html/ogrf.grad.ku.ac.th/form-gen/ (stored 0%)
#   adding: content/html/ogrf.grad.ku.ac.th/form-gen/index.html (deflated 78%)
#   adding: content/html/mis.ku.ac.th/ (stored 0%)
#   adding: content/html/mis.ku.ac.th/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6597/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6597/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=1/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=1/index.html (deflated 84%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=11/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=11/index.html (deflated 83%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=238/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=238/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=1915/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=1915/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=88/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=88/index.html (deflated 80%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6488/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6488/index.html (deflated 79%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=275/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=275/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6694/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6694/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=4865/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=4865/index.html (deflated 81%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6561/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6561/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6717/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6717/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=273/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=273/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=231/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=231/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=7/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=7/index.html (deflated 83%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=2/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=2/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=240/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=240/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/index.html (deflated 87%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6690/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6690/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=236/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=236/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=6/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=6/index.html (deflated 83%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=234/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=234/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=3/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}cat=3/index.html (deflated 83%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=4858/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=4858/index.html (deflated 80%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=471/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=471/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=242/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=242/index.html (deflated 78%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=280/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}page_id=280/index.html (deflated 81%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6668/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6668/index.html (deflated 82%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6714/ (stored 0%)
#   adding: content/html/sbc.ku.ac.th/{question}p=6714/index.html (deflated 82%)
#   adding: content/html/course.ku.ac.th/ (stored 0%)
#   adding: content/html/course.ku.ac.th/lms/ (stored 0%)
#   adding: content/html/course.ku.ac.th/lms/login1/ (stored 0%)
#   adding: content/html/course.ku.ac.th/lms/login1/ilogins.php/ (stored 0%)
#   adding: content/html/course.ku.ac.th/lms/login1/ilogins.php/index.html (deflated 78%)
#   adding: content/html/www.person.ku.ac.th/ (stored 0%)
#   adding: content/html/www.person.ku.ac.th/training/ (stored 0%)
#   adding: content/html/www.person.ku.ac.th/training/kukm/ (stored 0%)
#   adding: content/html/www.person.ku.ac.th/training/kukm/index.html (deflated 54%)
#   adding: content/html/www.person.ku.ac.th/stat.html/ (stored 0%)
#   adding: content/html/www.person.ku.ac.th/stat.html/index.html (deflated 73%)
#   adding: content/html/pr.ku.ac.th/ (stored 0%)
#   adding: content/html/pr.ku.ac.th/index.html (deflated 80%)
#   adding: content/html/www.grad.ku.ac.th/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/aboutithesis2019/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/aboutithesis2019/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/ข่าวบัณฑิตวิทยาลัย/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/ข่าวบัณฑิตวิทยาลัย/index.html (deflated 84%)
#   adding: content/html/www.grad.ku.ac.th/en/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/en/graduatecomplete/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/en/graduatecomplete/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/เกณฑ์มาตรฐานหลักสูตร/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกณฑ์มาตรฐานหลักสูตร/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/graduatecomplete/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/graduatecomplete/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/graduate_bord101163/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/graduate_bord101163/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/published_is/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/published_is/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/form_-teacher/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/form_-teacher/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/graduateonlineservice/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/graduateonlineservice/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/ติดต่อเรา/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/ติดต่อเรา/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/application/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/แบบฟอร์ม-ภาควิชา-ปกติ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/แบบฟอร์ม-ภาควิชา-ปกติ/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/application/อัตราค่าธรรมเนียมการศึ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/อัตราค่าธรรมเนียมการศึ/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/application/liststd_64_f1/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/liststd_64_f1/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/application/reporting/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/reporting/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/application/app63_f2_s/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/app63_f2_s/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/application/list_exam64_f1/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/list_exam64_f1/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/application/app63_f2/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/app63_f2/index.html (deflated 86%)
#   adding: content/html/www.grad.ku.ac.th/application/app64_f1_s/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/app64_f1_s/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/application/app64_f1/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/application/app64_f1/index.html (deflated 87%)
#   adding: content/html/www.grad.ku.ac.th/กำหนดหลักเกณฑ์การมอบทุ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/กำหนดหลักเกณฑ์การมอบทุ/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/dlm_uploads/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/dlm_uploads/2019/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/dlm_uploads/2019/08/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/dlm_uploads/2019/08/predegreeformprofession62.docx/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/dlm_uploads/2019/08/predegreeformprofession62.docx/index.html (deflated 58%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/2020/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/2020/12/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/2020/12/2021-2-2048x1365.jpg/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/wp-content/uploads/2020/12/2021-2-2048x1365.jpg/index.html (deflated 66%)
#   adding: content/html/www.grad.ku.ac.th/คำถามที่พบบ่อย/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/คำถามที่พบบ่อย/index.html (deflated 83%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/บัณฑิตวิทยาลัย/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/บัณฑิตวิทยาลัย/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/บุคลากร/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/บุคลากร/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/คณะผู้บริหาร-2/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับเรา/คณะผู้บริหาร-2/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/robots.txt (deflated 25%)
#   adding: content/html/www.grad.ku.ac.th/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารดาวน์โหลด/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารดาวน์โหลด/อาจารย์พิเศษ-ภายนอก-มก/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารดาวน์โหลด/อาจารย์พิเศษ-ภายนอก-มก/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารดาวน์โหลด/ขึ้นทะเบียนอาจารย์บัณฑ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารดาวน์โหลด/ขึ้นทะเบียนอาจารย์บัณฑ/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารดาวน์โหลด/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/category/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/ทุนการศึกษาวิจัย/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/ทุนการศึกษาวิจัย/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/category/ข่าวประกาศ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/ข่าวประกาศ/index.html (deflated 83%)
#   adding: content/html/www.grad.ku.ac.th/category/ข่าวทั่วไป/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/ข่าวทั่วไป/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/category/กิจกรรม/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/กิจกรรม/index.html (deflated 84%)
#   adding: content/html/www.grad.ku.ac.th/category/รับสมัครงาน/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/รับสมัครงาน/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/category/การศึกษาต่อ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/category/การศึกษาต่อ/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/gspp_63_f1/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/gspp_63_f1/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารประกอบการปฐมนิเท/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เอกสารประกอบการปฐมนิเท/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/approve_degree_schedule/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/approve_degree_schedule/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/มหาบัณฑิต-ปีการศึกษา-2563/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/มหาบัณฑิต-ปีการศึกษา-2563/index.html (deflated 90%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/ดุษฎีบัณฑิต-ปีการศึกษา-2563/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/ดุษฎีบัณฑิต-ปีการศึกษา-2563/index.html (deflated 89%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/เกณฑ์มาตรฐานหลักสูตร/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/เกณฑ์มาตรฐานหลักสูตร/index.html (deflated 83%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/78958/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/78958/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/index.html (deflated 83%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/คุณสมบัติของผู้เข้าศึก/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/curriculum/คุณสมบัติของผู้เข้าศึก/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับ-บว/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับ-บว/รางวัล/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกี่ยวกับ-บว/รางวัล/index.html (deflated 84%)
#   adding: content/html/www.grad.ku.ac.th/changeofservice/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/changeofservice/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/บริการนิสิต/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/บริการนิสิต/ระบบส่งข้อมูลการเผยแพร/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/บริการนิสิต/ระบบส่งข้อมูลการเผยแพร/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/ทุนการศึกษา/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/ทุนการศึกษา/index.html (deflated 87%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การศึกษาค้นคว้าอิสระ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การศึกษาค้นคว้าอิสระ/การรับเล่มปกแข็งและซีด-3/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การศึกษาค้นคว้าอิสระ/การรับเล่มปกแข็งและซีด-3/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การศึกษาค้นคว้าอิสระ/การส่งหลักฐานประกอบการ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การศึกษาค้นคว้าอิสระ/การส่งหลักฐานประกอบการ/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/การพิมพ์วิทยานิพนธ์/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/การพิมพ์วิทยานิพนธ์/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/การส่งต้นฉบับวิทยานิพน-2/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/การส่งต้นฉบับวิทยานิพน-2/index.html (deflated 83%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/การรับเล่มปกแข็งและซีด-2/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/การรับเล่มปกแข็งและซีด-2/index.html (deflated 84%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/โครงการวิทยานิพนธ์/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/วิทยานิพนธ์/โครงการวิทยานิพนธ์/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การเผยแพร่ผลงาน/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การเผยแพร่ผลงาน/การศึกษาค้นคว้าอิสระ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การเผยแพร่ผลงาน/การศึกษาค้นคว้าอิสระ/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การเผยแพร่ผลงาน/วิทยานิพนธ์/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การเผยแพร่ผลงาน/วิทยานิพนธ์/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/สอบปากเปล่าขั้นสุดท้าย/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/สอบปากเปล่าขั้นสุดท้าย/index.html (deflated 85%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/การสอบประมวลความรู้/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/การสอบประมวลความรู้/index.html (deflated 84%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/การสอบภาษาต่างประเทศ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การสอบ/การสอบภาษาต่างประเทศ/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/ปฏิทินการศึกษา/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/ปฏิทินการศึกษา/index.html (deflated 86%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การลงทะเบียน/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/นิสิต/การลงทะเบียน/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/announcethesis241163/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/announcethesis241163/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/เกณฑ์การสอบภาษาอังกฤษ/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/เกณฑ์การสอบภาษาอังกฤษ/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/2020/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/11/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/11/03/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/11/03/ขอเชิญ-ขอเชิญคณะภาควิชา/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/11/03/ขอเชิญ-ขอเชิญคณะภาควิชา/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/คณบดีบัณฑิตวิทยาลัย-ร่ว/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/คณบดีบัณฑิตวิทยาลัย-ร่ว/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/ผู้บริหารและบุคลากรบัณ-3/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/ผู้บริหารและบุคลากรบัณ-3/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/ผู้บริหารและบุคลากรบัณ-2/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/28/ผู้บริหารและบุคลากรบัณ-2/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/23/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/23/ขั้นตอนการรายงานตัวนิส/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/23/ขั้นตอนการรายงานตัวนิส/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/18/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/18/บัณฑิตวิทยาลัยร่วมงานว-5/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/12/18/บัณฑิตวิทยาลัยร่วมงานว-5/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/2020/03/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/03/25/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/03/25/เปิดรับนิสิตระดับปริญญ-2/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/2020/03/25/เปิดรับนิสิตระดับปริญญ-2/index.html (deflated 82%)
#   adding: content/html/www.grad.ku.ac.th/directline/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/directline/index.html (deflated 80%)
#   adding: content/html/www.grad.ku.ac.th/รายงานประจำปี/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/รายงานประจำปี/index.html (deflated 81%)
#   adding: content/html/www.grad.ku.ac.th/อาจารย์/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/อาจารย์/กฎระเบียบแต่งตั้งประกา/ (stored 0%)
#   adding: content/html/www.grad.ku.ac.th/อาจารย์/กฎระเบียบแต่งตั้งประกา/index.html (deflated 82%)
#   adding: content/html/tax-finance.psd.ku.ac.th:8443/ (stored 0%)
#   adding: content/html/tax-finance.psd.ku.ac.th:8443/index.html (deflated 69%)
#   adding: content/html/eces.psd.ku.ac.th/ (stored 0%)
#   adding: content/html/eces.psd.ku.ac.th/index.html (deflated 80%)
#   adding: content/html/rdi.ku.ac.th/ (stored 0%)
#   adding: content/html/rdi.ku.ac.th/index.html (deflated 18%)
#   adding: content/html/qa.src.ku.ac.th/ (stored 0%)
#   adding: content/html/qa.src.ku.ac.th/admission/ (stored 0%)
#   adding: content/html/qa.src.ku.ac.th/admission/index.html (deflated 82%)
#   adding: content/html/kukr2.lib.ku.ac.th/ (stored 0%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/ (stored 0%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/covid19/ (stored 0%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/covid19/index.html (deflated 88%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/kukr/ (stored 0%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/kukr/index.html (deflated 87%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/bkn_grad/ (stored 0%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/bkn_grad/index.html (deflated 86%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/drought/ (stored 0%)
#   adding: content/html/kukr2.lib.ku.ac.th/kukr_es/drought/index.html (deflated 85%)
#   adding: content/html/list_robot.txt (deflated 76%)
#   adding: content/html/archives.lib.ku.ac.th/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/pre1.php{question}id=10/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/pre1.php{question}id=10/index.html (deflated 81%)
#   adding: content/html/archives.lib.ku.ac.th/symbol.php/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/symbol.php/index.html (deflated 84%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=8/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=8/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=6/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=6/index.html (deflated 81%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=2/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=2/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=12/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=12/index.html (deflated 81%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=4/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=4/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chancellor.php/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chancellor.php/index.html (deflated 85%)
#   adding: content/html/archives.lib.ku.ac.th/conference.php/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/conference.php/index.html (deflated 83%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=7/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=7/index.html (deflated 81%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=5/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=5/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=3/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=3/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=11/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=11/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/index.html (deflated 93%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=10/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=10/index.html (deflated 81%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=1/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=1/index.html (deflated 85%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=14/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=14/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=9/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=9/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=13/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/chan_page1.php{question}id=13/index.html (deflated 82%)
#   adding: content/html/archives.lib.ku.ac.th/db-time_line-detail.php{question}id=45/ (stored 0%)
#   adding: content/html/archives.lib.ku.ac.th/db-time_line-detail.php{question}id=45/index.html (deflated 83%)
#   adding: content/html/tourist.bus.ku.ac.th/ (stored 0%)
#   adding: content/html/tourist.bus.ku.ac.th/index.html (deflated 77%)
#   adding: content/html/ku-press.ku.ac.th/ (stored 0%)
#   adding: content/html/ku-press.ku.ac.th/robots.txt (deflated 59%)
#   adding: content/html/ku-press.ku.ac.th/index.html (deflated 94%)
#   adding: content/html/www.sdgs.ku.ac.th/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-case/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-case/index.html (deflated 85%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-professor-involved-in-national-policy-towards-sustainable-development/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-professor-involved-in-national-policy-towards-sustainable-development/index.html (deflated 76%)
#   adding: content/html/www.sdgs.ku.ac.th/kasetsart-university-and-recoftc-innovating-sustainable-partnerships-for-people-and-forests/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/kasetsart-university-and-recoftc-innovating-sustainable-partnerships-for-people-and-forests/index.html (deflated 75%)
#   adding: content/html/www.sdgs.ku.ac.th/the-netherlands-thailand-livestock-forum-2019/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/the-netherlands-thailand-livestock-forum-2019/index.html (deflated 73%)
#   adding: content/html/www.sdgs.ku.ac.th/sdg-ku-way/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/sdg-ku-way/index.html (deflated 77%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-professor-involved-in-national-policy-towards-smart-farming-by-the-ministry-of-agriculture-and-cooperatives/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-professor-involved-in-national-policy-towards-smart-farming-by-the-ministry-of-agriculture-and-cooperatives/index.html (deflated 75%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-sdgs/ (stored 0%)
#   adding: content/html/www.sdgs.ku.ac.th/ku-sdgs/index.html (deflated 83%)
#   adding: content/html/www.sdgs.ku.ac.th/robots.txt (deflated 25%)
#   adding: content/html/www.sdgs.ku.ac.th/index.html (deflated 78%)
# ...
#   adding: content/html/www.ku.ac.th/th/scholarships-at-ku/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/scholarships-at-ku/index.html (deflated 84%)
#   adding: content/html/www.ku.ac.th/th/jobnews-ku{question}category=61/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/jobnews-ku{question}category=61/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/associate-institution/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/associate-institution/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/faculty-and-department/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/faculty-and-department/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/short-course/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/short-course/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/president-s-palace/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/president-s-palace/index.html (deflated 81%)
#   adding: content/html/www.ku.ac.th/th/alumni/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/alumni/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/central-procurement-ku{question}category=57/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/central-procurement-ku{question}category=57/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/philosophy-vision-mission/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/philosophy-vision-mission/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/community-home/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/community-home/index.html (deflated 86%)
#   adding: content/html/www.ku.ac.th/th/research-station-center/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/research-station-center/index.html (deflated 81%)
#   adding: content/html/www.ku.ac.th/th/sports-and-health/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/sports-and-health/index.html (deflated 79%)
#   adding: content/html/www.ku.ac.th/th/section-structure/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/section-structure/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/recruitment/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/recruitment/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/landmark/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/landmark/index.html (deflated 82%)
#   adding: content/html/www.ku.ac.th/th/the-identity-of-ku/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/the-identity-of-ku/index.html (deflated 79%)
#   adding: content/html/www.ku.ac.th/th/jobnews-ku{question}category=60/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/jobnews-ku{question}category=60/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/jobnews-ku{question}category=69/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/jobnews-ku{question}category=69/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/university-information/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/university-information/index.html (deflated 81%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/179/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/179/index.html (deflated 58%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/178/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/178/index.html (deflated 83%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/177/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/university-information/go/177/index.html (deflated 83%)
#   adding: content/html/www.ku.ac.th/th/learning-resources/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/learning-resources/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th/related-links/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/related-links/index.html (deflated 81%)
#   adding: content/html/www.ku.ac.th/th/car-service-routes-in-maha-vickya-sai/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th/car-service-routes-in-maha-vickya-sai/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/graduate-degree-program/ (stored 0%)
#   adding: content/html/www.ku.ac.th/graduate-degree-program/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-veterinary-science-ku/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-veterinary-science-ku/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-social-sciences/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-social-sciences/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse59/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse59/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/office-of-promotion-and-training/ (stored 0%)
#   adding: content/html/www.ku.ac.th/office-of-promotion-and-training/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse62/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse62/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/faculty-of-liberal-arts-and-management-science/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-liberal-arts-and-management-science/index.html (deflated 82%)
#   adding: content/html/www.ku.ac.th/sirindhorn-international-center-for-research-development-and-technology-transfer/ (stored 0%)
#   adding: content/html/www.ku.ac.th/sirindhorn-international-center-for-research-development-and-technology-transfer/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/sports-science/ (stored 0%)
#   adding: content/html/www.ku.ac.th/sports-science/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/index.php/ (stored 0%)
#   adding: content/html/www.ku.ac.th/index.php/index.html (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-humanities/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-humanities/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse1/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse1/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/kasetsart-university-foundation/ (stored 0%)
#   adding: content/html/www.ku.ac.th/kasetsart-university-foundation/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/kasetsart-university-savings-and-credit-cooperative/ (stored 0%)
#   adding: content/html/www.ku.ac.th/kasetsart-university-savings-and-credit-cooperative/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-natural-resources-and-agro-industry/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-natural-resources-and-agro-industry/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/jobs/ (stored 0%)
#   adding: content/html/www.ku.ac.th/jobs/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/local/ (stored 0%)
#   adding: content/html/www.ku.ac.th/local/lists/ (stored 0%)
#   adding: content/html/www.ku.ac.th/local/lists/245019872666104/ (stored 0%)
#   adding: content/html/www.ku.ac.th/local/lists/245019872666104/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-kamphaeng-saen-campus/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-kamphaeng-saen-campus/index.html (deflated 81%)
#   adding: content/html/www.ku.ac.th/th#adm-news/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#adm-news/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/short-course/ (stored 0%)
#   adding: content/html/www.ku.ac.th/short-course/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-agro-industry/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-agro-industry/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-forestry/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-forestry/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/fundraisers/ (stored 0%)
#   adding: content/html/www.ku.ac.th/fundraisers/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#new/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#new/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/food-and-drink/ (stored 0%)
#   adding: content/html/www.ku.ac.th/food-and-drink/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-environment/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-environment/index.html (deflated 83%)
#   adding: content/html/www.ku.ac.th/around-university-fence{question}category=16&amp;keysearch=/ (stored 0%)
#   adding: content/html/www.ku.ac.th/around-university-fence{question}category=16&amp;keysearch=/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/lite/ (stored 0%)
#   adding: content/html/www.ku.ac.th/lite/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse3/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse3/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/institute-of-food-research-and-product-development/ (stored 0%)
#   adding: content/html/www.ku.ac.th/institute-of-food-research-and-product-development/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/dormitory/ (stored 0%)
#   adding: content/html/www.ku.ac.th/dormitory/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse61/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse61/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/office-of-education-administration/ (stored 0%)
#   adding: content/html/www.ku.ac.th/office-of-education-administration/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse6/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse6/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/campus-office1/ (stored 0%)
#   adding: content/html/www.ku.ac.th/campus-office1/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-sriracha-campus/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-sriracha-campus/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-engineering-at-kamphaeng-saen/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-engineering-at-kamphaeng-saen/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/th#collapse63/ (stored 0%)
#   adding: content/html/www.ku.ac.th/th#collapse63/index.html (deflated 75%)
#   adding: content/html/www.ku.ac.th/royal-project-foundation/ (stored 0%)
#   adding: content/html/www.ku.ac.th/royal-project-foundation/index.html (deflated 79%)
#   adding: content/html/www.ku.ac.th/tuition-fees/ (stored 0%)
#   adding: content/html/www.ku.ac.th/tuition-fees/index.html (deflated 81%)
#   adding: content/html/www.ku.ac.th/faculty-of-economics-at-si-racha/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-economics-at-si-racha/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/faculty-of-science-at-siracha/ (stored 0%)
#   adding: content/html/www.ku.ac.th/faculty-of-science-at-siracha/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/places/ (stored 0%)
#   adding: content/html/www.ku.ac.th/places/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/campus-office/ (stored 0%)
#   adding: content/html/www.ku.ac.th/campus-office/index.html (deflated 80%)
#   adding: content/html/www.ku.ac.th/car-service-routes-in-maha-vickya-sai/ (stored 0%)
#   adding: content/html/www.ku.ac.th/car-service-routes-in-maha-vickya-sai/index.html (deflated 80%)
#   adding: content/html/airq.ku.ac.th/ (stored 0%)
#   adding: content/html/airq.ku.ac.th/index.php/ (stored 0%)
#   adding: content/html/airq.ku.ac.th/index.php/index.html (deflated 78%)
#   adding: content/html/directory.ku.ac.th/ (stored 0%)
#   adding: content/html/directory.ku.ac.th/index.html (deflated 42%)
#   adding: content/html/directory.ku.ac.th/ver3/ (stored 0%)
#   adding: content/html/directory.ku.ac.th/ver3/index.php/ (stored 0%)
#   adding: content/html/directory.ku.ac.th/ver3/index.php/index.html (deflated 42%)
#   adding: content/html/research.ku.ac.th/ (stored 0%)
#   adding: content/html/research.ku.ac.th/forest/ (stored 0%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=03^M^J/ (stored 0%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=03^M^J/index.html (deflated 77%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=01 ^M^J/ (stored 0%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=01 ^M^J/index.html (deflated 82%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=04 / (stored 0%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=04 /index.html (deflated 78%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=02^M^J/ (stored 0%)
#   adding: content/html/research.ku.ac.th/forest/department.aspx{question}campusid=02^M^J/index.html (deflated 78%)
#   adding: content/html/web.sbc.ku.ac.th/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=149/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=149/index.html (deflated 82%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=3962/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=3962/index.html (deflated 79%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=6060/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=6060/index.html (deflated 79%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-2.jpg/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-2.jpg/index.html (deflated 59%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-6.jpg/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-6.jpg/index.html (deflated 59%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-1.jpg/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-1.jpg/index.html (deflated 58%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-5.jpg/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-5.jpg/index.html (deflated 59%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-3.jpg/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/wp-content/uploads/2016/09/image-3.jpg/index.html (deflated 59%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=4660/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=4660/index.html (deflated 79%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=5066/ (stored 0%)
#   adding: content/html/web.sbc.ku.ac.th/newsupan/{question}page_id=5066/index.html (deflated 79%)
#   adding: content/html/mailto:hrd_etoku@ku.ac.th/ (stored 0%)
#   adding: content/html/mailto:hrd_etoku@ku.ac.th/index.html (deflated 75%)
#   adding: content/html/cb.ku.ac.th/ (stored 0%)
#   adding: content/html/cb.ku.ac.th/apply/ (stored 0%)
#   adding: content/html/cb.ku.ac.th/apply/signin.php/ (stored 0%)
#   adding: content/html/cb.ku.ac.th/apply/signin.php/index.html (deflated 74%)
#   adding: content/html/cb.ku.ac.th/apply/index.php/ (stored 0%)
#   adding: content/html/cb.ku.ac.th/apply/index.php/index.html (deflated 85%)

# %%
from google.colab import files
files.download("/content/test/html.zip")
